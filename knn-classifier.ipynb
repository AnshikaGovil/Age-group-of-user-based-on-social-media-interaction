# %%
import sys
# !cp ../input/rapids/rapids.0.15.0 /opt/conda/envs/rapids.tar.gz
# !cd /opt/conda/envs/ && tar -xzvf rapids.tar.gz > /dev/null
sys.path = ["/opt/conda/envs/rapids/lib/python3.6/site-packages"] + sys.path
sys.path = ["/opt/conda/envs/rapids/lib/python3.6"] + sys.path
sys.path = ["/opt/conda/envs/rapids/lib"] + sys.path 
# !cp /opt/conda/envs/rapids/lib/libxgboost.so /opt/conda/lib/

# %%
import numpy as np 
import pandas as pd 
import matplotlib.pyplot as plt
from scipy.stats import mode
from sklearn.metrics import f1_score, accuracy_score
from cuml.neighbors import KNeighborsClassifier, NearestNeighbors
import cuml; cuml.__version__
# Out:
# '0.16.0'

# %%
import pandas as pd
pd.set_option('display.max_columns', 500)
import time
import numpy as np
import xgboost as xgb
from sklearn.model_selection import StratifiedKFold
from sklearn.metrics import f1_score, accuracy_score

# %%
train = pd.read_csv('/kaggle/input/Cascade_cup/train_age_dataset.csv')
test = pd.read_csv('/kaggle/input/Cascade_cup/test_age_dataset.csv')
sample = pd.read_csv('/kaggle/Cascade_cup/sample_submission.csv')

# %%
train
# Out:
#         Unnamed: 0    userId  tier  gender  following_rate  followers_avg_age  \
# 0           265153  48958844     2       1        0.000000              0.000
# 1           405231  51100441     2       2        0.000000              0.000
# 2            57867   6887426     2       1        0.000000              0.000
# 3           272618  50742404     2       1        0.000000              0.000
# 4           251123  45589200     2       2        0.000000              0.000
# ...            ...       ...   ...     ...             ...                ...
# 488872      535266  38983571     2       2        0.000000              0.000
# 488873       36706  53264639     1       1        0.017241              0.000
# 488874       31570  44693578     1       1        0.229508              1.625
# 488875      239209  42760145     2       1        0.000000              0.000
# 488876      238035  42482997     2       1        0.000000              0.000
#
#         following_avg_age  max_repetitive_punc  num_of_hashtags_per_action  \
# 0                    0.00                    0                         0.0
# 1                    0.00                    0                         0.0
# 2                    0.00                    0                         0.0
# 3                    0.00                    0                         0.0
# 4                    0.00                    0                         0.0
# ...                   ...                  ...                         ...
# 488872               0.00                    0                         0.0
# 488873               0.00                    0                         0.0
# 488874               2.25                    0                         0.0
# 488875               0.00                    0                         0.0
# 488876               0.00                    0                         0.0
#
#         emoji_count_per_action  punctuations_per_action  \
# 0                          0.0                 0.000000
# 1                          0.0                 0.076923
# 2                          0.0                 0.000000
# 3                          0.0                 0.000000
# 4                          0.0                 0.000000
# ...                        ...                      ...
# 488872                     0.0                 0.000000
# 488873                     0.0                 0.000000
# 488874                     0.0                 0.000000
# 488875                     0.0                 0.000000
# 488876                     0.0                 0.000000
#
#         number_of_words_per_action  avgCompletion  avgTimeSpent  avgDuration  \
# 0                         0.000000       0.463330     34.160000    53.996091
# 1                         0.153846       0.429468     15.285714    96.231625
# 2                         0.000000       0.341657     22.000000    83.051415
# 3                         0.000000       0.005735      3.000000   523.080000
# 4                         0.000000       0.456549     12.333333    53.766640
# ...                            ...            ...           ...          ...
# 488872                    0.300000       0.422837      8.714286    56.783167
# 488873                    0.012195       0.668494     35.662921    69.031216
# 488874                    0.094340       0.579213     13.444444    50.611380
# 488875                    0.000000       0.221303      9.578947   131.188182
# 488876                    0.000000       0.253091      3.142857    10.550500
#
#         avgComments  creations  content_views  num_of_comments  \
# 0                 0   0.000000       0.200000         0.000000
# 1                 0   0.008475       0.093220         0.000000
# 2                 0   0.000000       0.002786         0.000000
# 3                 0   0.000000       0.008403         0.000000
# 4                 0   0.000000       0.204918         0.000000
# ...             ...        ...            ...              ...
# 488872            0   0.008000       0.064000         0.000000
# 488873            2   0.051724       2.043103         0.017241
# 488874            0   0.016393       0.409836         0.000000
# 488875            0   0.000000       0.113821         0.000000
# 488876            0   0.000000       0.073171         0.000000
#
#         weekends_trails_watched_per_day  weekdays_trails_watched_per_day  \
# 0                              0.041667                         0.025000
# 1                              0.012712                         0.018644
# 2                              0.000000                         0.000557
# 3                              0.000000                         0.001681
# 4                              0.000000                         0.049180
# ...                                 ...                              ...
# 488872                         0.012000                         0.006400
# 488873                         0.301724                         0.339655
# 488874                         0.000000                         0.118033
# 488875                         0.000000                         0.030894
# 488876                         0.000000                         0.011382
#
#         slot1_trails_watched_per_day  slot2_trails_watched_per_day  \
# 0                           0.000000                      0.000000
# 1                           0.000000                      0.084746
# 2                           0.000000                      0.002786
# 3                           0.000000                      0.000000
# 4                           0.000000                      0.008197
# ...                              ...                           ...
# 488872                      0.000000                      0.008000
# 488873                      0.068966                      0.922414
# 488874                      0.000000                      0.049180
# 488875                      0.000000                      0.024390
# 488876                      0.000000                      0.000000
#
#         slot3_trails_watched_per_day  slot4_trails_watched_per_day  \
# 0                           0.175000                      0.033333
# 1                           0.000000                      0.033898
# 2                           0.000000                      0.000000
# 3                           0.000000                      0.008403
# 4                           0.057377                      0.180328
# ...                              ...                           ...
# 488872                      0.000000                      0.048000
# 488873                      0.137931                      1.172414
# 488874                      0.237705                      0.303279
# 488875                      0.130081                      0.000000
# 488876                      0.056911                      0.000000
#
#              avgt2  age_group
# 0         0.000000          1
# 1        82.500000          2
# 2         0.000000          1
# 3         0.000000          1
# 4         0.000000          1
# ...            ...        ...
# 488872  195.000000          1
# 488873  188.742857          4
# 488874  184.880000          4
# 488875    0.000000          1
# 488876    0.000000          1
#
# [488877 rows x 27 columns]

# %%
train = pd.get_dummies(train, columns=['tier','gender'])
test = pd.get_dummies(test, columns=['tier','gender'])

train['age_group'] = train['age_group']-1

feature_cols = [col for col in train.columns.tolist() if col not in ['age_group', ]]
target_cols = ['age_group']

# KFOLD
skf = StratifiedKFold(n_splits=5, random_state=0, shuffle=True)

for i, (trn, val) in enumerate(skf.split(train[target_cols], train[target_cols])):
    train.loc[val, 'kfold'] = i
train['kfold'] = train['kfold'].astype(int)

# %%
train
# Out:
#         Unnamed: 0    userId  following_rate  followers_avg_age  \
# 0           265153  48958844        0.000000              0.000
# 1           405231  51100441        0.000000              0.000
# 2            57867   6887426        0.000000              0.000
# 3           272618  50742404        0.000000              0.000
# 4           251123  45589200        0.000000              0.000
# ...            ...       ...             ...                ...
# 488872      535266  38983571        0.000000              0.000
# 488873       36706  53264639        0.017241              0.000
# 488874       31570  44693578        0.229508              1.625
# 488875      239209  42760145        0.000000              0.000
# 488876      238035  42482997        0.000000              0.000
#
#         following_avg_age  max_repetitive_punc  num_of_hashtags_per_action  \
# 0                    0.00                    0                         0.0
# 1                    0.00                    0                         0.0
# 2                    0.00                    0                         0.0
# 3                    0.00                    0                         0.0
# 4                    0.00                    0                         0.0
# ...                   ...                  ...                         ...
# 488872               0.00                    0                         0.0
# 488873               0.00                    0                         0.0
# 488874               2.25                    0                         0.0
# 488875               0.00                    0                         0.0
# 488876               0.00                    0                         0.0
#
#         emoji_count_per_action  punctuations_per_action  \
# 0                          0.0                 0.000000
# 1                          0.0                 0.076923
# 2                          0.0                 0.000000
# 3                          0.0                 0.000000
# 4                          0.0                 0.000000
# ...                        ...                      ...
# 488872                     0.0                 0.000000
# 488873                     0.0                 0.000000
# 488874                     0.0                 0.000000
# 488875                     0.0                 0.000000
# 488876                     0.0                 0.000000
#
#         number_of_words_per_action  avgCompletion  avgTimeSpent  avgDuration  \
# 0                         0.000000       0.463330     34.160000    53.996091
# 1                         0.153846       0.429468     15.285714    96.231625
# 2                         0.000000       0.341657     22.000000    83.051415
# 3                         0.000000       0.005735      3.000000   523.080000
# 4                         0.000000       0.456549     12.333333    53.766640
# ...                            ...            ...           ...          ...
# 488872                    0.300000       0.422837      8.714286    56.783167
# 488873                    0.012195       0.668494     35.662921    69.031216
# 488874                    0.094340       0.579213     13.444444    50.611380
# 488875                    0.000000       0.221303      9.578947   131.188182
# 488876                    0.000000       0.253091      3.142857    10.550500
#
#         avgComments  creations  content_views  num_of_comments  \
# 0                 0   0.000000       0.200000         0.000000
# 1                 0   0.008475       0.093220         0.000000
# 2                 0   0.000000       0.002786         0.000000
# 3                 0   0.000000       0.008403         0.000000
# 4                 0   0.000000       0.204918         0.000000
# ...             ...        ...            ...              ...
# 488872            0   0.008000       0.064000         0.000000
# 488873            2   0.051724       2.043103         0.017241
# 488874            0   0.016393       0.409836         0.000000
# 488875            0   0.000000       0.113821         0.000000
# 488876            0   0.000000       0.073171         0.000000
#
#         weekends_trails_watched_per_day  weekdays_trails_watched_per_day  \
# 0                              0.041667                         0.025000
# 1                              0.012712                         0.018644
# 2                              0.000000                         0.000557
# 3                              0.000000                         0.001681
# 4                              0.000000                         0.049180
# ...                                 ...                              ...
# 488872                         0.012000                         0.006400
# 488873                         0.301724                         0.339655
# 488874                         0.000000                         0.118033
# 488875                         0.000000                         0.030894
# 488876                         0.000000                         0.011382
#
#         slot1_trails_watched_per_day  slot2_trails_watched_per_day  \
# 0                           0.000000                      0.000000
# 1                           0.000000                      0.084746
# 2                           0.000000                      0.002786
# 3                           0.000000                      0.000000
# 4                           0.000000                      0.008197
# ...                              ...                           ...
# 488872                      0.000000                      0.008000
# 488873                      0.068966                      0.922414
# 488874                      0.000000                      0.049180
# 488875                      0.000000                      0.024390
# 488876                      0.000000                      0.000000
#
#         slot3_trails_watched_per_day  slot4_trails_watched_per_day  \
# 0                           0.175000                      0.033333
# 1                           0.000000                      0.033898
# 2                           0.000000                      0.000000
# 3                           0.000000                      0.008403
# 4                           0.057377                      0.180328
# ...                              ...                           ...
# 488872                      0.000000                      0.048000
# 488873                      0.137931                      1.172414
# 488874                      0.237705                      0.303279
# 488875                      0.130081                      0.000000
# 488876                      0.056911                      0.000000
#
#              avgt2  age_group  tier_1  tier_2  tier_3  gender_1  gender_2  \
# 0         0.000000          0       0       1       0         1         0
# 1        82.500000          1       0       1       0         0         1
# 2         0.000000          0       0       1       0         1         0
# 3         0.000000          0       0       1       0         1         0
# 4         0.000000          0       0       1       0         0         1
# ...            ...        ...     ...     ...     ...       ...       ...
# 488872  195.000000          0       0       1       0         0         1
# 488873  188.742857          3       1       0       0         1         0
# 488874  184.880000          3       1       0       0         1         0
# 488875    0.000000          0       0       1       0         1         0
# 488876    0.000000          0       0       1       0         1         0
#
#         kfold
# 0           1
# 1           3
# 2           4
# 3           2
# 4           3
# ...       ...
# 488872      2
# 488873      1
# 488874      0
# 488875      1
# 488876      4
#
# [488877 rows x 31 columns]

# %%
from sklearn.ensemble import RandomForestClassifier

def run_training():
    oof = np.zeros((train.shape[0], 4))
    pred = np.zeros((test.shape[0], 4))
    
    for fold in range(5):
        print(f"\nStarting FOLD: {fold}")
        start = time.time()
        

        trn_idx = train['kfold'] != fold
        val_idx = train['kfold'] == fold
        trn = train.loc[trn_idx, :]
        val = train.loc[val_idx, :]

        xtr, ytr = trn[feature_cols].values, trn[target_cols].values
        xval, yval = val[feature_cols].values, val[target_cols].values
        xtest = test[feature_cols].values

        model = KNeighborsClassifier(n_neighbors=15)
        print("fitting model...")                           
        model.fit(xtr, ytr.reshape(-1,))
        print("Calculating training preds ...")
        train_preds = model.predict(xtr)
        print("Calculating validation preds ...")
        val_preds = model.predict(xval)
        print("Training Accuracy Score - ", accuracy_score(ytr, train_preds ))
        print("Training F1 Score - ", f1_score(ytr, train_preds, average='weighted'))
        
        print("Validation Accuracy Score - ", accuracy_score(yval, val_preds))
        print("Validation F1 Score - ", f1_score(yval, val_preds, average='weighted'))
        
        oof[val_idx, :] += model.predict_proba(xval)
        
        # Test preds
        pred += model.predict_proba(xtest)/5
        
        print(f"FOLD {fold} completed in {time.time()-start} seconds")
        
    return oof, pred

# %%
oof_knn, pred_knn= run_training()
# Out:
# Starting FOLD: 0
# fitting model...
# Calculating training preds ...
# Calculating validation preds ...
# Training Accuracy Score -  0.8001794932766728
# Training F1 Score -  0.7841217001117853
# Validation Accuracy Score -  0.7758754704630993
# Validation F1 Score -  0.758637938320528
# FOLD 0 completed in 6.750045537948608 seconds
#
# Starting FOLD: 1
# fitting model...
# Calculating training preds ...
# Calculating validation preds ...
# Training Accuracy Score -  0.7997959606342095
# Training F1 Score -  0.7833698197915135
# Validation Accuracy Score -  0.7803039600720013
# Validation F1 Score -  0.7626273192266874
# FOLD 1 completed in 6.535984754562378 seconds
#
# Starting FOLD: 2
# fitting model...
# Calculating training preds ...
# Calculating validation preds ...
# Training Accuracy Score -  0.7998169275534259
# Training F1 Score -  0.7838750291004574
# Validation Accuracy Score -  0.7801482996676042
# Validation F1 Score -  0.7627380558337287
# FOLD 2 completed in 6.649160861968994 seconds
#
# Starting FOLD: 3
# fitting model...
# Calculating training preds ...
# Calculating validation preds ...
# Training Accuracy Score -  0.799617491089281
# Training F1 Score -  0.7835197207382953
# Validation Accuracy Score -  0.7787675786243927
# Validation F1 Score -  0.761415937433406
# FOLD 3 completed in 6.612124919891357 seconds
#
# Starting FOLD: 4
# fitting model...
# Calculating training preds ...
# Calculating validation preds ...
# Training Accuracy Score -  0.8006939366201145
# Training F1 Score -  0.7844564210718656
# Validation Accuracy Score -  0.7787982613142419
# Validation F1 Score -  0.7618110703987794
# FOLD 4 completed in 6.531054973602295 seconds

# %%
def find_oof_score(oof):
    predictions = oof.argmax(axis=1)
    print("OOF Accuracy Score - ", accuracy_score(train[target_cols], predictions))
    print("OOF F1 Score - ", f1_score(train[target_cols], predictions, average='weighted'))

# %%
find_oof_score(oof_knn)
# Out:
# OOF Accuracy Score -  0.7787787112095681
# OOF F1 Score -  0.7614467451484419

# %%
pred_knn.shape
# Out:
# (54320, 4)

# %%
final_preds = pred_rf.argmax(axis=1)+1
pred_csv = pd.DataFrame(final_preds.reshape(-1), columns=['prediction'] )
pred_csv
# Out:
#        prediction
# 0               1
# 1               1
# 2               1
# 3               3
# 4               1
# ...           ...
# 54315           1
# 54316           2
# 54317           4
# 54318           1
# 54319           1
#
# [54320 rows x 1 columns]

# %%
pred_csv.value_counts()
# Out:
# prediction
# 1             36294
# 2              8172
# 3              7182
# 4              2672
# dtype: int64

# %%
pred_csv.to_csv('knn.csv', index=False)

# %%
np.save('oof_knn.npy', oof_knn)
np.save('pred_knn.npy', pred_knn)
